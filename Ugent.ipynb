# %%
import pandas as pd
import preprocessor as p

# %%
data = pd.read_csv('zxc.csv')

# %%
data
# Out:
#        Unnamed: 0  Unnamed: 0.1                     author publicationTime  \
# 0               0             0  id:twitter.com:2209799083      2016-10-02
# 1               1             1  id:twitter.com:2209799083      2016-10-02
# 2               2             2    id:twitter.com:43060113      2016-10-02
# 3               3             3  id:twitter.com:2209799083      2016-10-02
# 4               4             4   id:twitter.com:585560584      2016-10-02
# 5               5             5   id:twitter.com:149770065      2016-10-02
# 6               6             6   id:twitter.com:585560584      2016-10-02
# 7               7             7  id:twitter.com:1542665564      2016-10-02
# 8               8             8  id:twitter.com:3051674485      2016-10-02
# 9               9             9    id:twitter.com:53313129      2016-10-02
# 10             10            10   id:twitter.com:177799795      2016-10-02
# ...

# %%
data['Clean'] = data['Clean_Data'].apply(lambda x : p.clean(str(x)))

# %%
data['Clean'].head()
# Out:
# 0    : Adani Group's Aust mining troubles far from ...
# 1        : Poor old . Now even is moving away from it.
# 2    : Funds have burned billions of dollars of our...
# 3    : PM Announces Retreat from Coal Power. Anothe...
# 4    : Adani Group's Aust mining troubles far from ...
# Name: Clean, dtype: object

# %%
data['Clean'][1]
# Out:
# u': Poor old . Now even is moving away from it.'

# %%
def clean_data(x):
    APPOSTOPHES = {"'s" : " is", "'re" : " are", ":" : "","&amp;":"","?":"",'"':""}
    words = x.split()
    reformed = [APPOSTOPHES[word] if word in APPOSTOPHES else word for word in words]
    reformed = " ".join(reformed)
    return (reformed)

# %%
data['Clean1'] = data['Clean'].apply(lambda x : clean_data(x))

# %%
data['Clean1']
# Out:
# 0         Adani Group's Aust mining troubles far from o...
# 1              Poor old . Now even is moving away from it.
# 2         Funds have burned billions of dollars of our ...
# 3         PM Announces Retreat from Coal Power. Another...
# 4         Adani Group's Aust mining troubles far from o...
# 5         How times change! Published on QLD Labor's Fa...
# 6         Ex commish lays it on the line: need overhaul...
# 7                     forum: Air ,  public  eerts from and
# 8        nature launched legal action against approval ...
# 9        Climate Angels Arrested For ?Watching Over? Sa...
# 10        Japan approves building of new coal-fired pow...
# 11                                                      NO
# 12        Govt's done a big  cleanup but will it tackle...
# 13       Possible Aus to India for via .Moving with tim...
# 14       Australia's landholders are up in arms everywh...
# 15        Australia's landholders are up in arms everyw...
# ...

# %%
data.to_csv('asd.csv')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
documents=("AMMAMS","L KAPOOR")

tfidf_vectorizer=TfidfVectorizer()
tfidf_matrix=tfidf_vectorizer.fit_transform(documents)
#print tfidf_matrix.shape

cs=cosine_similarity(tfidf_matrix[0:1],tfidf_matrix)
print cs
# Out:
# [[ 1.  0.]]

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                     author publicationTime  \
# 0           0             0  id:twitter.com:2209799083      2016-10-02
# 1           1             1  id:twitter.com:2209799083      2016-10-02
# 2           2             2    id:twitter.com:43060113      2016-10-02
# 3           3             3  id:twitter.com:2209799083      2016-10-02
# 4           4             4   id:twitter.com:585560584      2016-10-02
#
#                                             bodyText  \
# 0  RT @350Australia: Adani Group's Aust #coal min...
# 1  RT @avivaimhof: Poor old #coal. Now even #Viet...
# 2  RT @market_forces: Funds have burned billions ...
# 3  RT @avivaimhof: #Vietnam PM Announces Retreat ...
# 4  RT @350Australia: Adani Group's Aust #coal min...
#
#                                           Clean_Data  \
# 0  RT @350Australia: Adani Group's Aust #coal min...
# 1  RT @avivaimhof: Poor old #coal. Now even #Viet...
# ...

# %%
unique_date = data['publicationTime'].unique()

# %%
len(unique_date)
# Out:
# 33

# %%
# Out:
# '2016-10-02'

# %%
Data_1 = data[data['publicationTime'] == unique_date[0]]
Data_2 = data[data['publicationTime'] == unique_date[1]]
Data_3 = data[data['publicationTime'] == unique_date[2]]
Data_4 = data[data['publicationTime'] == unique_date[3]]
Data_5 = data[data['publicationTime'] == unique_date[4]]
Data_6 = data[data['publicationTime'] == unique_date[5]]
Data_7 = data[data['publicationTime'] == unique_date[6]]
Data_8 = data[data['publicationTime'] == unique_date[7]]
Data_9 = data[data['publicationTime'] == unique_date[8]]
Data_10 = data[data['publicationTime'] == unique_date[9]]
Data_11 = data[data['publicationTime'] == unique_date[10]]
Data_12 = data[data['publicationTime'] == unique_date[11]]
Data_13 = data[data['publicationTime'] == unique_date[12]]
Data_14 = data[data['publicationTime'] == unique_date[13]]
Data_15 = data[data['publicationTime'] == unique_date[14]]
Data_16 = data[data['publicationTime'] == unique_date[15]]
Data_17 = data[data['publicationTime'] == unique_date[16]]
Data_18 = data[data['publicationTime'] == unique_date[17]]
Data_19 = data[data['publicationTime'] == unique_date[18]]
Data_20 = data[data['publicationTime'] == unique_date[19]]
Data_21 = data[data['publicationTime'] == unique_date[20]]
Data_22 = data[data['publicationTime'] == unique_date[21]]
Data_23 = data[data['publicationTime'] == unique_date[22]]
Data_24 = data[data['publicationTime'] == unique_date[23]]
Data_25 = data[data['publicationTime'] == unique_date[24]]
Data_26 = data[data['publicationTime'] == unique_date[25]]
Data_27 = data[data['publicationTime'] == unique_date[26]]
Data_28 = data[data['publicationTime'] == unique_date[27]]
Data_29 = data[data['publicationTime'] == unique_date[28]]
Data_30 = data[data['publicationTime'] == unique_date[29]]
Data_31 = data[data['publicationTime'] == unique_date[30]]
Data_32 = data[data['publicationTime'] == unique_date[31]]
Data_33 = data[data['publicationTime'] == unique_date[32]]

# %%
Data_3.head()
# Out:
#      Unnamed: 0  Unnamed: 0.1                     author publicationTime  \
# 482         482           482    id:twitter.com:41482051      2016-12-02
# 483         483           483  id:twitter.com:4896271660      2016-12-02
# 484         484           484   id:twitter.com:227783748      2016-12-02
# 485         485           485  id:twitter.com:1559468120      2016-12-02
# 486         486           486  id:twitter.com:3186440924      2016-12-02
#
#                                               bodyText  \
# 482  URGENT PETITION calling on the @NHMRC to study...
# 483  Counter strike Global Offensive | Unlucky Ace ...
# 484  RT @GGlo2422: needs attention @SenatorNash #cs...
# 485  RT @StopShenhua: "People are absolutely furiou...
# 486  RT @AustralisTerry: The National Coal &amp; Ga...
#
#                                             Clean_Data  \
# 482  URGENT PETITION calling on the @NHMRC to study...
# 483  Counter strike Global Offensive | Unlucky Ace ...
# ...

# %%
import re, math
from collections import Counter

WORD = re.compile(r'\w+')

def get_cosine(vec1, vec2):
     vec1 = text_to_vector(vec1)
     vec2 = text_to_vector(vec2)
     intersection = set(vec1.keys()) & set(vec2.keys())
     numerator = sum([vec1[x] * vec2[x] for x in intersection])

     sum1 = sum([vec1[x]**2 for x in vec1.keys()])
     sum2 = sum([vec2[x]**2 for x in vec2.keys()])
     denominator = math.sqrt(sum1) * math.sqrt(sum2)

     if not denominator:
        return 0.0
     else:
        return float(numerator) / denominator

def text_to_vector(text):
     words = WORD.findall(text)
     return Counter(words)

text1 = 'This is a foo bar sentence .'
text2 = 'This sentence is similar to a foo bar sentence .'

#vector1 = text_to_vector(text1)
#vector2 = text_to_vector(text2)

cosine = get_cosine(text1, text2)

print 'Cosine:', cosine
# Out:
# Cosine: 0.861640436855

# %%
len(Data_3)
# Out:
# 79

# %%
cosine = get_cosine(CosineData['Clean1'][0], CosineData['Clean1'][1])
# Out:
# 0.111111111111

# %%
CosineData = pd.read_csv('Cosine.csv')

# %%
import numpy as np
Cosine = ''
CosineCoff = []

# %%
len(CosineData)
# Out:
# 262

# %%
for i in range(len(CosineData)):
    for j in range(len(CosineData)):
        Cosine = get_cosine(CosineData['Clean1'][i], CosineData['Clean1'][j])
        CosineCoff.append(Cosine)

# %%
x = np.reshape(CosineCoff, (262, 262))

# %%
len(CosineCoff)
# Out:
# 68644

# %%
type(x)
# Out:
# numpy.ndarray

# %%
np.savetxt("1234.csv", x, delimiter=",")
